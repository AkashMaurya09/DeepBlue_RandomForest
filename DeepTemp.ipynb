# %%
import pandas as pd
features = pd.read_csv('test.csv')
features.head(5)
# Out:
#    Number in the queue/DeptNumber  Shift (M/A/E)  Queue Type (Reg  \
# 0                             102              3                1
# 1                             103              3                1
# 2                             102              3                1
# 3                             101              1                1
# 4                             102              1                1
#
#    Service Point   Created Queue Hours  Created Queue Day of Week  \
# 0               3                   11                          7
# 1               3                   19                          1
# 2               4                   15                          7
# 3               3                   15                          3
# 4               1                   14                          7
#
#    Waiting Duration  Number of Waiting Queue  Arrival Rate  Service Rate  \
# 0                16                        1             9            10
# 1                26                        4            10             8
# 2                33                        8             7             9
# 3                33                        6             3             8
# 4                21                        1             3             8
#
#    Average Wait Time
# 0          55.868426
# 1          28.501161
# 2          19.162552
# 3          43.272158
# 4          51.714694

# %%
print('The shape of our features is:', features.shape)
# Out:
# The shape of our features is: (70, 11)

# %%
features.describe()
# Out:
#        Number in the queue/DeptNumber  Shift (M/A/E)  Queue Type (Reg  \
# count                       70.000000      70.000000        70.000000
# mean                       223.400000       2.128571         2.214286
# std                         84.834434       0.899620         0.849430
# min                        101.000000       1.000000         1.000000
# 25%                        103.000000       1.000000         1.000000
# 50%                        203.000000       2.000000         2.000000
# 75%                        302.000000       3.000000         3.000000
# max                        303.000000       3.000000         3.000000
#
#        Service Point   Created Queue Hours  Created Queue Day of Week  \
# count       70.000000            70.000000                  70.000000
# mean         2.571429            13.957143                   4.000000
# std          1.136629             3.827572                   1.985454
# min          1.000000             8.000000                   1.000000
# 25%          2.000000            11.000000                   2.000000
# 50%          3.000000            14.000000                   4.000000
# 75%          4.000000            17.000000                   6.000000
# max          4.000000            20.000000                   7.000000
#
#        Waiting Duration  Number of Waiting Queue  Arrival Rate  Service Rate  \
# count         70.000000                70.000000     70.000000     70.000000
# mean          40.071429                 4.914286      6.671429      8.928571
# std           13.288680                 2.887970      2.557860      0.804362
# min           15.000000                 0.000000      3.000000      8.000000
# 25%           30.000000                 3.000000      4.000000      8.000000
# 50%           40.000000                 5.000000      7.000000      9.000000
# 75%           51.750000                 7.000000      9.000000     10.000000
# max           60.000000                10.000000     10.000000     10.000000
#
#        Average Wait Time
# count          70.000000
# mean           38.450017
# std            12.266130
# min            15.999804
# 25%            28.500507
# 50%            36.188951
# 75%            49.919999
# max            59.621743

# %%
features = pd.get_dummies(features)

# %%
features.iloc[:,5:].head(5)
# Out:
#    Created Queue Day of Week  Waiting Duration  Number of Waiting Queue  \
# 0                          7                16                        1
# 1                          1                26                        4
# 2                          7                33                        8
# 3                          3                33                        6
# 4                          7                21                        1
#
#    Arrival Rate  Service Rate  Average Wait Time
# 0             9            10          55.868426
# 1            10             8          28.501161
# 2             7             9          19.162552
# 3             3             8          43.272158
# 4             3             8          51.714694

# %%
import numpy as np
# Labels are the values we want to predict
labels = np.array(features['Waiting Duration'])
# Remove the labels from the features
# axis 1 refers to the columns
features= features.drop('Waiting Duration', axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
features = np.array(features)

# %%
from sklearn.model_selection import train_test_split
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (52, 10)
# Training Labels Shape: (52,)
# Testing Features Shape: (18, 10)
# Testing Labels Shape: (18,)

# %%
baseline_preds = test_features[:, feature_list.index('Average Wait Time')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Out:
# Average baseline error:  15.11

# %%
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 12.33 degrees.

# %%
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 61.21 %.
